# %% [markdown]
# # V15 Confirmatory Analysis
#
# This notebook is the deterministic reader-facing entry point for the exact-2.7.3 V15 confirmatory study. It fails closed on missing run receipts, duplicate immutable evidence, or missing blinded grading data.

# %% [markdown]
# ## Context & Methods
#
# The notebook loads the frozen protocol, validates every immutable run receipt against its evidence manifest, requires a blinded three-grader panel JSON under `analysis/blinded_grading.json`, and only then writes statistical tables and figures. No USD estimates are inferred.

# %%
import json
from analysis.pipeline import preflight_report, run_confirmatory_analysis, study_paths

paths = study_paths()
report = preflight_report(paths=paths)
print(json.dumps(report, indent=2))
# Out:
# {
#   "protocolId": "memi-2.7-v15-2.7.3-confirmatory-protocol",
#   "expectedCells": 36,
#   "expectedTrials": 36,
#   "presentTrials": 36,
#   "missingTrials": [],
#   "duplicateTrials": {},
#   "extraTrials": [],
#   "gradeOnlyExclusions": [
#     "memi-2.7-v15-2.7.3-confirmatory:buzzr-tab-unread-badge:r6:memi",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r1:baseline",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r1:memi",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r2:baseline",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r2:memi",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r3:baseline",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r3:memi",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r4:baseline",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r4:memi",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r5:baseline",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r5:memi",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r6:baseline",
#     "memi-2.7-v15-2.7.3-confirmatory:nate-options-reduce-motion:r6:memi",
#     "memi-2.7-v15-2.7.3-confirmatory:paraform-command-menu:r5:baseline"
#   ],
#   "blindedGradingPath": "/Volumes/ExtremeSSD/Projects/_worktrees/memi-v15-confirmatory/docs/research/memi-2.7-prospective-study/v15-2.7.3-confirmatory/analysis/blinded_grading.json",
#   "blindedGradingPresent": true,
#   "errors": []
# }

# %%
summary = run_confirmatory_analysis(write_outputs=True)
print(json.dumps(summary['primarySummary'], indent=2))
# Out:
# [
#   {
#     "task_id": "buzzr-tab-unread-badge",
#     "graded_pairs": 5,
#     "mean_delta": 1.4,
#     "median_delta": 1.0,
#     "sign_test_positive": 4,
#     "sign_test_negative": 1,
#     "sign_test_ties": 0,
#     "sign_test_p_greater": 0.1875,
#     "bootstrap_ci_lower_2p5": 0.0,
#     "bootstrap_ci_upper_97p5": 2.8,
#     "noninferiority_lower_95_one_sided": 0.2,
#     "noninferiority_margin": -5.0,
#     "noninferior": true
#   },
#   {
#     "task_id": "paraform-command-menu",
#     "graded_pairs": 5,
#     "mean_delta": -0.4,
#     "median_delta": 2.0,
#     "sign_test_positive": 3,
#     "sign_test_negative": 2,
#     "sign_test_ties": 0,
#     "sign_test_p_greater": 0.5,
#     "bootstrap_ci_lower_2p5": -4.2,
#     "bootstrap_ci_upper_97p5": 2.8,
#     "noninferiority_lower_95_one_sided": -3.4,
#     "noninferiority_margin": -5.0,
#     "noninferior": true
#   }
# ]

# %% [markdown]
# ## Results
#
# If the previous cell completed, the generated tables now live under `generated/tables/` and the figures under `generated/figures/`.

# %% [markdown]
# ## Takeaways
#
# Interpretation must be read from the executed outputs above. If the notebook stopped with an error, the confirmatory study is still blocked and no inferential result should be cited.
